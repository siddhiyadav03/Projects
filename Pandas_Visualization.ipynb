# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings(action="ignore")

# %%
df=pd.read_csv('choclate protfolio project - 11.csv')

# %%
#displays all the data
df
# Out:
#         Sales Person    Geography               Product   Amount  Units
# 0         Ram Mahesh  New Zealand        70% Dark Bites  $1,624     114  \
# 1        Brien Boise          USA  Choco Coated Almonds  $6,706     459
# 2       Husein Augar          USA          Almond Choco    $959     147
# 3       Carla Molina       Canada         Drinking Coco  $9,632     288
# 4     Curtice Advani           UK            White Choc  $2,100     414
# ..               ...          ...                   ...      ...    ...
# 295  Gunar Cockshoot  New Zealand          Almond Choco    $938     366
# 296  Gunar Cockshoot    Australia   Baker's Choco Chips  $8,841     303
# 297     Barr Faughny           UK   Peanut Butter Cubes  $4,018     126
# 298     Carla Molina  New Zealand       Raspberry Choco    $714     231
# 299     Husein Augar    Australia            White Choc  $3,850     102
#
#      cost per unit   Cost    Profit profit %
# 0               14  1,652     ($28)      -2%
# ...

# %%
#displays first 5 rows
df.head()
# Out:
#      Sales Person    Geography               Product   Amount  Units
# 0      Ram Mahesh  New Zealand        70% Dark Bites  $1,624     114  \
# 1     Brien Boise          USA  Choco Coated Almonds  $6,706     459
# 2    Husein Augar          USA          Almond Choco    $959     147
# 3    Carla Molina       Canada         Drinking Coco  $9,632     288
# 4  Curtice Advani           UK            White Choc  $2,100     414
#
#    cost per unit   Cost    Profit profit %
# 0             14  1,652     ($28)      -2%
# 1              9  3,970   $2,736       41%
# 2             12  1,746    ($787)     -82%
# 3              6  1,863   $7,769       81%
# 4             13  5,444  ($3,344)    -159%

# %%
#returns the number of missing values in the dataset
df.isnull().sum()
# Out:
# Sales Person     0
# Geography        0
# Product          0
# Amount           0
# Units            0
# cost per unit    0
# Cost             0
# Profit           0
# profit %         0
# dtype: int64

# %%
#returns the label of each column in the datadrame
df.columns
# Out:
# Index(['Sales Person', 'Geography', 'Product', 'Amount', 'Units',
#        'cost per unit', 'Cost', 'Profit', 'profit %'],
#       dtype='object')

# %%
#prints information of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   300 non-null    object
#  1   Geography      300 non-null    object
#  2   Product        300 non-null    object
#  3   Amount         300 non-null    object
#  4   Units          300 non-null    int64
#  5   cost per unit  300 non-null    int64
#  6   Cost           300 non-null    object
#  7   Profit         300 non-null    object
#  8   profit %       300 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 21.2+ KB

# %%
#replaces the specified value with a new value
#df.replace()
df["Amount"]=df["Amount"].str.replace("$"," ")
df["Amount"]=df["Amount"].str.replace(",","")
df["Amount"]=df["Amount"].astype("int64")
df
# Out:
#         Sales Person    Geography               Product  Amount  Units
# 0         Ram Mahesh  New Zealand        70% Dark Bites    1624    114  \
# 1        Brien Boise          USA  Choco Coated Almonds    6706    459
# 2       Husein Augar          USA          Almond Choco     959    147
# 3       Carla Molina       Canada         Drinking Coco    9632    288
# 4     Curtice Advani           UK            White Choc    2100    414
# ..               ...          ...                   ...     ...    ...
# 295  Gunar Cockshoot  New Zealand          Almond Choco     938    366
# 296  Gunar Cockshoot    Australia   Baker's Choco Chips    8841    303
# 297     Barr Faughny           UK   Peanut Butter Cubes    4018    126
# 298     Carla Molina  New Zealand       Raspberry Choco     714    231
# 299     Husein Augar    Australia            White Choc    3850    102
#
#      cost per unit   Cost    Profit profit %
# 0               14  1,652     ($28)      -2%
# ...

# %%
df["Cost"]=df["Cost"].str.replace("$"," ")
df["Cost"]=df["Cost"].str.replace(",","")
df["Cost"]=df["Cost"].astype(int)

# %%
df
# Out:
#         Sales Person    Geography               Product  Amount  Units
# 0         Ram Mahesh  New Zealand        70% Dark Bites    1624    114  \
# 1        Brien Boise          USA  Choco Coated Almonds    6706    459
# 2       Husein Augar          USA          Almond Choco     959    147
# 3       Carla Molina       Canada         Drinking Coco    9632    288
# 4     Curtice Advani           UK            White Choc    2100    414
# ..               ...          ...                   ...     ...    ...
# 295  Gunar Cockshoot  New Zealand          Almond Choco     938    366
# 296  Gunar Cockshoot    Australia   Baker's Choco Chips    8841    303
# 297     Barr Faughny           UK   Peanut Butter Cubes    4018    126
# 298     Carla Molina  New Zealand       Raspberry Choco     714    231
# 299     Husein Augar    Australia            White Choc    3850    102
#
#      cost per unit  Cost    Profit profit %
# 0               14  1652     ($28)      -2%
# ...

# %%
#replace geography with countries
df.rename(columns={'Geography': 'Countries'},inplace=True)
df
# Out:
#         Sales Person    Countries               Product  Amount  Units
# 0         Ram Mahesh  New Zealand        70% Dark Bites    1624    114  \
# 1        Brien Boise          USA  Choco Coated Almonds    6706    459
# 2       Husein Augar          USA          Almond Choco     959    147
# 3       Carla Molina       Canada         Drinking Coco    9632    288
# 4     Curtice Advani           UK            White Choc    2100    414
# ..               ...          ...                   ...     ...    ...
# 295  Gunar Cockshoot  New Zealand          Almond Choco     938    366
# 296  Gunar Cockshoot    Australia   Baker's Choco Chips    8841    303
# 297     Barr Faughny           UK   Peanut Butter Cubes    4018    126
# 298     Carla Molina  New Zealand       Raspberry Choco     714    231
# 299     Husein Augar    Australia            White Choc    3850    102
#
#      cost per unit  Cost    Profit profit %
# 0               14  1652     ($28)      -2%
# ...

# %%
#drop a specified column name
#The first argument, ["Profit", "profit %"], specifies the names of the columns to be dropped.
#The second argument, axis=1, specifies that the columns should be dropped along the "columns" axis (i.e., horizontally).
df.drop(['Profit','profit %'],axis=True)
df
# Out:
#         Sales Person    Countries               Product  Amount  Units
# 0         Ram Mahesh  New Zealand        70% Dark Bites    1624    114  \
# 1        Brien Boise          USA  Choco Coated Almonds    6706    459
# 2       Husein Augar          USA          Almond Choco     959    147
# 3       Carla Molina       Canada         Drinking Coco    9632    288
# 4     Curtice Advani           UK            White Choc    2100    414
# ..               ...          ...                   ...     ...    ...
# 295  Gunar Cockshoot  New Zealand          Almond Choco     938    366
# 296  Gunar Cockshoot    Australia   Baker's Choco Chips    8841    303
# 297     Barr Faughny           UK   Peanut Butter Cubes    4018    126
# 298     Carla Molina  New Zealand       Raspberry Choco     714    231
# 299     Husein Augar    Australia            White Choc    3850    102
#
#      cost per unit  Cost    Profit profit %
# 0               14  1652     ($28)      -2%
# ...

# %%
# to generate descriptive statistics of a Pandas DataFrame object df.
df.describe()
# Out:
#              Amount       Units  cost per unit         Cost
# count    300.000000  300.000000     300.000000   300.000000
# mean    4136.230000  152.200000       9.473333  1465.703333
# std     3124.832629  118.099499       3.457717  1363.647142
# min        0.000000    0.000000       3.000000     0.000000
# 25%     1652.000000   54.000000       6.000000   487.000000
# 50%     3437.000000  124.500000       9.000000  1079.000000
# 75%     6179.250000  220.500000      12.000000  2016.750000
# max    16184.000000  525.000000      17.000000  8683.000000

# %%
#sort the Pandas DataFrame object df in ascending order based on the values in the "Profit" column. 
df.sort_values(by=['Profit'],ascending=True)
# Out:
#         Sales Person    Countries              Product  Amount  Units
# 97   Gunar Cockshoot       Canada      99% Dark & Pure    1281     18  \
# 180   Curtice Advani    Australia            Milk Bars    2317    123
# 277      Brien Boise    Australia  Organic Choco Syrup    2268     63
# 42    Curtice Advani        India      Raspberry Choco    1442     15
# 190     Husein Augar           UK        Drinking Coco    2639    204
# ..               ...          ...                  ...     ...    ...
# 78      Husein Augar          USA  Baker's Choco Chips      98    159
# 58      Husein Augar  New Zealand   Manuka Honey Choco    1085    273
# 59      Gigi Bohling  New Zealand   Smooth Sliky Salty     182     48
# 153       Ram Mahesh           UK   Manuka Honey Choco       0    135
# 27        Oby Sorrel          USA         Orange Choco    1974    195
#
#      cost per unit  Cost   Profit profit %
# 97               8   138  $1,143       89%
# ...

# %%
#unique values of the "Countries" column from the Pandas DataFrame object df. 
df['Countries'].unique()
# Out:
# array(['New Zealand', 'USA', 'Canada', 'UK', 'Australia', 'India'],
#       dtype=object)

# %%
#create a new Pandas DataFrame object df_new by grouping the existing DataFrame object df by the "Countries" column 
#And calculate the sum of the "Profit" column for each group.
df_new=df[['Countries','Profit']].groupby('Countries')['Profit'].sum()
df_new   #the variable df_new,  has the "Countries" column as its index and a single "Profit" column as the summed values for each country.
# Out:
# Countries
# Australia      $2,368 $404 $1,591 $182 $827 ($3,584)$3,424 $4...
# Canada         $7,769 $8,156 $6,217 $8,882 $15,841 ($70)$7,67...
# India          ($252)$12,010 ($1,071)$7,571 $2,613 $30 $6,635...
# New Zealand    ($28)$4,851 $3,535 $7,189 $212 $4,488 $5,891 (...
# UK             ($3,344)($4,290)$7,723 ($1,456)$4,369 $5,700 $...
# USA            $2,736 ($787)$3,525 $2,960 ($613)$1,641 ($68)(...
# Name: Profit, dtype: object

# %%
#replace()
df['Profit']=df['Profit'].str.replace('$','')
df['Profit']=df['Profit'].str.replace('(','-')
df['Profit']=df['Profit'].str.replace(')','')
df['Profit']=df['Profit'].str.replace(',','')
df
# Out:
#         Sales Person    Countries               Product  Amount  Units
# 0         Ram Mahesh  New Zealand        70% Dark Bites    1624    114  \
# 1        Brien Boise          USA  Choco Coated Almonds    6706    459
# 2       Husein Augar          USA          Almond Choco     959    147
# 3       Carla Molina       Canada         Drinking Coco    9632    288
# 4     Curtice Advani           UK            White Choc    2100    414
# ..               ...          ...                   ...     ...    ...
# 295  Gunar Cockshoot  New Zealand          Almond Choco     938    366
# 296  Gunar Cockshoot    Australia   Baker's Choco Chips    8841    303
# 297     Barr Faughny           UK   Peanut Butter Cubes    4018    126
# 298     Carla Molina  New Zealand       Raspberry Choco     714    231
# 299     Husein Augar    Australia            White Choc    3850    102
#
#      cost per unit  Cost Profit profit %
# 0               14  1652    -28      -2%
# ...

# %%
#convert the data type of the "Profit" column from a non-integer type to an integer type using the astype() method.
df['Profit'] = df['Profit'].astype(int)

# %%
#display the summary information of the Pandas DataFrame object df 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sales Person   300 non-null    object
#  1   Countries      300 non-null    object
#  2   Product        300 non-null    object
#  3   Amount         300 non-null    int64
#  4   Units          300 non-null    int64
#  5   cost per unit  300 non-null    int64
#  6   Cost           300 non-null    int32
#  7   Profit         300 non-null    int32
#  8   profit %       300 non-null    object
# dtypes: int32(2), int64(3), object(4)
# memory usage: 18.9+ KB

# %%
#sort the Pandas DataFrame object df in ascending order based on the values in the "Profit" column.
df.sort_values(by=['Profit'],ascending=True)
# Out:
#        Sales Person  Countries               Product  Amount  Units
# 101    Barr Faughny     Canada   Organic Choco Syrup     798    519  \
# 10     Barr Faughny         UK            White Choc    1785    462
# 161      Ram Mahesh        USA        70% Dark Bites    2275    447
# 145     Brien Boise  Australia             Milk Bars     819    510
# 35   Curtice Advani  Australia   Organic Choco Syrup    1134    282
# ..              ...        ...                   ...     ...    ...
# 106    Barr Faughny     Canada       Mint Chip Choco   11417     21
# 17     Gigi Bohling      India          Orange Choco   15610    339
# 165      Oby Sorrel         UK   Peanut Butter Cubes   12950     30
# 72     Husein Augar      India  Caramel Stuffed Bars   14329    150
# 50     Gigi Bohling     Canada       Mint Chip Choco   16184     39
#
#      cost per unit  Cost  Profit profit %
# 101             17  8683   -7885    -988%
# 10              13  6075   -4290    -240%
# ...

# %%
#creates a new Pandas DataFrame object data_pivot using the pivot_table() method to summarize the data in the original DataFrame df.
data_pivot=pd.pivot_table(df,index="Countries",values="Amount",aggfunc="sum")
data_pivot
# Out:
#              Amount
# Countries
# Australia    168679
# Canada       237944
# India        252469
# New Zealand  218813
# UK           173530
# USA          189434

# %%
#create a new column named "Profit" that represents the profit earned for each transaction.
df["Profit"]=df["Amount"]-df["Cost"]
df
# Out:
#         Sales Person    Countries               Product  Amount  Units
# 0         Ram Mahesh  New Zealand        70% Dark Bites    1624    114  \
# 1        Brien Boise          USA  Choco Coated Almonds    6706    459
# 2       Husein Augar          USA          Almond Choco     959    147
# 3       Carla Molina       Canada         Drinking Coco    9632    288
# 4     Curtice Advani           UK            White Choc    2100    414
# ..               ...          ...                   ...     ...    ...
# 295  Gunar Cockshoot  New Zealand          Almond Choco     938    366
# 296  Gunar Cockshoot    Australia   Baker's Choco Chips    8841    303
# 297     Barr Faughny           UK   Peanut Butter Cubes    4018    126
# 298     Carla Molina  New Zealand       Raspberry Choco     714    231
# 299     Husein Augar    Australia            White Choc    3850    102
#
#      cost per unit  Cost  Profit profit %  Profit_percent
# ...

# %%
#create a new column named "Profit_percent" that represents the percentage of profit earned for each transaction.
df["Profit_percent"]=((df["Amount"]-df["Cost"])/df["Amount"])*100
df
# Out:
#         Sales Person    Countries               Product  Amount  Units
# 0         Ram Mahesh  New Zealand        70% Dark Bites    1624    114  \
# 1        Brien Boise          USA  Choco Coated Almonds    6706    459
# 2       Husein Augar          USA          Almond Choco     959    147
# 3       Carla Molina       Canada         Drinking Coco    9632    288
# 4     Curtice Advani           UK            White Choc    2100    414
# ..               ...          ...                   ...     ...    ...
# 295  Gunar Cockshoot  New Zealand          Almond Choco     938    366
# 296  Gunar Cockshoot    Australia   Baker's Choco Chips    8841    303
# 297     Barr Faughny           UK   Peanut Butter Cubes    4018    126
# 298     Carla Molina  New Zealand       Raspberry Choco     714    231
# 299     Husein Augar    Australia            White Choc    3850    102
#
#      cost per unit  Cost  Profit profit %  Profit_percent
# ...

# %%
#group the rows in df by two columns, "Countries" and "Product", and then calculate the sum of the "Profit" column for each group.
df2=df[['Countries','Profit','Product']].groupby(['Countries','Product'])['Profit'].sum()
df2
# Out:
# Countries  Product
# Australia  50% Dark Bites          -154
#            70% Dark Bites          5608
#            85% Dark Bars           4209
#            99% Dark & Pure         4190
#            After Nines             6060
#                                   ...
# USA        Peanut Butter Cubes     -643
#            Raspberry Choco        21860
#            Smooth Sliky Salty      3329
#            Spicy Special Slims    -1485
#            White Choc              -613
# Name: Profit, Length: 119, dtype: int64

# %%
#group the rows in df by the "Product" column, and then calculate the sum of the "Profit" column for each group.
df3=df[['Product','Profit']].groupby('Product')['Profit'].sum()
df3
# Out:
# Product
# 50% Dark Bites          19525
# 70% Dark Bites          25899
# 85% Dark Bars           30189
# 99% Dark & Pure         29797
# After Nines             46236
# Almond Choco            14946
# Baker's Choco Chips     58278
# Caramel Stuffed Bars    39084
# Choco Coated Almonds    52062
# Drinking Coco           40815
# Eclairs                 56473
# Fruit & Nut Bars        44882
# Manuka Honey Choco      36700
# Milk Bars               29720
# Mint Chip Choco         43178
# Orange Choco            31391
# Organic Choco Syrup     19572
# Peanut Butter Cubes     46226
# Raspberry Choco         50988
# Smooth Sliky Salty      29518
# Spicy Special Slims     26000
# White Choc              29679
# Name: Profit, dtype: int64

# %%
# select only the rows where the "Profit" column is less than zero.
df_losses=df[df['Profit']<0]
df_losses
# Out:
#         Sales Person    Countries              Product  Amount  Units
# 0         Ram Mahesh  New Zealand       70% Dark Bites    1624    114  \
# 2       Husein Augar          USA         Almond Choco     959    147
# 4     Curtice Advani           UK           White Choc    2100    414
# 10      Barr Faughny           UK           White Choc    1785    462
# 13      Barr Faughny        India            Milk Bars     252     54
# ..               ...          ...                  ...     ...    ...
# 259      Brien Boise  New Zealand  Spicy Special Slims     434     87
# 264     Carla Molina          USA      99% Dark & Pure     609     99
# 268   Curtice Advani          USA         Orange Choco    1071    270
# 295  Gunar Cockshoot  New Zealand         Almond Choco     938    366
# 298     Carla Molina  New Zealand      Raspberry Choco     714    231
#
#      cost per unit  Cost  Profit profit %  Profit_percent
# 0               14  1652     -28      -2%       -1.724138
# ...

# %%
#sort the DataFrame in ascending order of the "Profit" column, so the products with the largest negative profit will appear at the top of the DataFrame.
df4=df_losses[['Product','Profit']].groupby('Product')['Profit'].sum().sort_values()
df4
# Out:
# Product
# Organic Choco Syrup    -17348
# 70% Dark Bites         -10829
# Almond Choco           -10127
# White Choc              -8886
# Milk Bars               -5696
# Peanut Butter Cubes     -4879
# Mint Chip Choco         -4539
# Caramel Stuffed Bars    -4270
# Spicy Special Slims     -4251
# 50% Dark Bites          -3511
# Orange Choco            -3046
# After Nines             -2285
# Raspberry Choco         -2064
# Manuka Honey Choco      -1837
# Baker's Choco Chips     -1836
# Drinking Coco           -1226
# 99% Dark & Pure          -776
# Choco Coated Almonds     -473
# Smooth Sliky Salty        -96
# Name: Profit, dtype: int64

# %%
#summary of the mean profit percentage for each combination of product and country.
data_pt_profit=pd.pivot_table(df,index=("Product"),columns=("Countries"),values=["Profit_percent"],aggfunc=(np.mean))
data_pt_profit.sort_values(by=("Product"),ascending=True)
# Out:
#                      Profit_percent
# Countries                 Australia       Canada       India  New Zealand
# Product
# 50% Dark Bites            10.744220          NaN  -33.964958    65.852482  \
# 70% Dark Bites            55.365781    49.998438  -55.878895 -1045.518022
# 85% Dark Bars             76.093380          NaN   89.404198    92.075649
# 99% Dark & Pure           76.543661    44.386249   38.703081    50.635877
# After Nines              -83.891695    95.139301  -53.797476    12.380443
# Almond Choco              85.791906    -5.695840   -8.571429  -606.480148
# Baker's Choco Chips       59.365326 -1065.306122   88.350466    80.919329
# Caramel Stuffed Bars      61.975909  -174.197176   50.666176    48.608761
# Choco Coated Almonds      73.659988    25.604044   69.413689          NaN
# Drinking Coco              1.743532    79.024814         NaN    74.214305
# Eclairs                   98.837209    59.666853   77.564459    91.588908
# ...

# %%
#highlight any cells with negative profit percentages in red.
styled_table = data_pt_profit.style.format('{:.2f}%').applymap(lambda x: 'background-color: red' if x < 0 else '')
styled_table
# Out:
# <style type="text/css">
# #T_612da_row0_col2, #T_612da_row1_col2, #T_612da_row1_col3, #T_612da_row1_col5, #T_612da_row4_col0, #T_612da_row4_col2, #T_612da_row5_col1, #T_612da_row5_col2, #T_612da_row5_col3, #T_612da_row5_col5, #T_612da_row6_col1, #T_612da_row6_col5, #T_612da_row7_col1, #T_612da_row9_col4, #T_612da_row13_col0, #T_612da_row13_col2, #T_612da_row14_col2, #T_612da_row14_col3, #T_612da_row14_col4, #T_612da_row15_col5, #T_612da_row16_col0, #T_612da_row16_col1, #T_612da_row16_col4, #T_612da_row16_col5, #T_612da_row17_col5, #T_612da_row18_col3, #T_612da_row20_col1, #T_612da_row20_col3, #T_612da_row20_col5, #T_612da_row21_col4, #T_612da_row21_col5 {
#   background-color: red;
# }
# </style>
# <table id="T_612da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_612da_level0_col0" class="col_heading level0 col0" colspan="6">Profit_percent</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Countries</th>
# ...

# %%
#summary of the total cost for each country.
top_country=pd.pivot_table(df,index="Countries",values="Cost",aggfunc=np.sum)
top_country
# Out:
#                Cost
# Countries
# Australia     60689
# Canada        68260
# India         80681
# New Zealand   68927
# UK            53941
# USA          107213

# %%
#summary of the total number of units sold by each sales person.
top_Sales_person=pd.pivot_table(df,index="Sales Person",values="Units",aggfunc=np.sum)
top_Sales_person.head(5)
# Out:
#                 Units
# Sales Person
# Barr Faughny     4110
# Brien Boise      4704
# Carla Molina     3867
# Ches Bonnell     5295
# Curtice Advani   5925

# %%
#create a new DataFrame data_numeric that contains only the columns from the original df DataFrame that have a numeric data type.
data_numeric=df.select_dtypes(include="int")
data_numeric
# Out:
#      Amount  Units  cost per unit  Cost  Profit
# 0      1624    114             14  1652     -28
# 1      6706    459              9  3970    2736
# 2       959    147             12  1746    -787
# 3      9632    288              6  1863    7769
# 4      2100    414             13  5444   -3344
# ..      ...    ...            ...   ...     ...
# 295     938    366             12  4348   -3410
# 296    8841    303              6  1697    7144
# 297    4018    126             12  1559    2459
# 298     714    231             12  2710   -1996
# 299    3850    102             13  1341    2509
#
# [300 rows x 5 columns]

# %% [markdown]
# Data Visualization

# %%
sns.scatterplot(data=df,x="Amount",y="Profit")
plt.show()

# %%
sns.scatterplot(data=df,x="Cost",y="Profit")
plt.show()

# %%
plt.figure(figsize = (12,5), dpi = 200)
plt.bar(df_new.index,df_new.values)
plt.title('Profit in Countries')
plt.xlabel('Country Name')
plt.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %%
plt.figure(figsize = (4,5), dpi = 200)
plt.pie(df_new.values,labels=df_new.index,autopct = '%1.2f%%')
plt.show()

# %%
plt.figure(figsize = (12,8), dpi = 200)
df3.plot.barh(x=df3.index, y=df3.values,title='Profit of each chocolate', color='green')
plt.xlabel('Profit')
plt.ylabel('Product')
# Out:
# Text(0, 0.5, 'Product')

# %%
plt.figure(figsize = (12,8), dpi = 200)
df4.plot.barh(x=df4.index, y=df4.values,title='Loss Occured', color='red')
plt.xlabel('Loss')
plt.ylabel('Product')
# Out:
# Text(0, 0.5, 'Product')
